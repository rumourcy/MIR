# %%
import os
import errno
import pandas as pd
import numpy as np
from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import audioFeatureExtraction
from sklearn.model_selection import train_test_split
from sklearn.metrics import zero_one_loss
from sklearn.metrics import classification_report
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
fold = RepeatedStratifiedKFold(n_splits=3, n_repeats=3, random_state=42)
import matplotlib.pyplot as plt
# %matplotlib inline

def mkdirp(path):
    try:
        os.makedirs(path)
    except OSError as exception:
        if exception.errno != errno.EEXIST:
            raise

# %%
dataRootDir = "./data"
featuresRootDir = "./features/"
mkdirp(featuresRootDir)

print("=====FEATURE EXTRACTION STARTING=====")
#Extract chroma features for the whole database and save them in featuresRootDir
mtWin = 1.0
mtStep = 1.0
stWin = 0.050
stStep = 0.025
for subdir, dirs, files in os.walk(dataRootDir):
    for file in files:
        if file[0] == ".":
            continue #This is for avoiding .DS_Store and similar files
        print("Extracting features for file " + os.path.join(subdir, file))
        featureClassDir = featuresRootDir + subdir[len(dataRootDir):];
        mkdirp(featureClassDir)
        audioFeatureExtraction.mtFeatureExtractionToFile(os.path.join(subdir, file), mtWin, mtStep, stWin, stStep,os.path.join(featureClassDir,file),storeStFeatures=True)

print("=====FEATURE EXTRACTION COMPLETE=====")
# Out:
# =====FEATURE EXTRACTION STARTING=====
# Extracting features for file ./data/a/a1.wav
# Extracting features for file ./data/a/a10.wav
# Extracting features for file ./data/a/a100.wav
# Extracting features for file ./data/a/a101.wav
# Extracting features for file ./data/a/a102.wav
# Extracting features for file ./data/a/a103.wav
# Extracting features for file ./data/a/a104.wav
# Extracting features for file ./data/a/a105.wav
# Extracting features for file ./data/a/a106.wav
# Extracting features for file ./data/a/a107.wav
# Extracting features for file ./data/a/a108.wav
# Extracting features for file ./data/a/a109.wav
# Extracting features for file ./data/a/a11.wav
# Extracting features for file ./data/a/a110.wav
# Extracting features for file ./data/a/a111.wav
# Extracting features for file ./data/a/a112.wav
# Extracting features for file ./data/a/a113.wav
# Extracting features for file ./data/a/a114.wav
# Extracting features for file ./data/a/a115.wav
# Extracting features for file ./data/a/a116.wav
# Extracting features for file ./data/a/a117.wav
# Extracting features for file ./data/a/a118.wav
# Extracting features for file ./data/a/a119.wav
# Extracting features for file ./data/a/a12.wav
# Extracting features for file ./data/a/a120.wav
# Extracting features for file ./data/a/a121.wav
# Extracting features for file ./data/a/a122.wav
# Extracting features for file ./data/a/a123.wav
# Extracting features for file ./data/a/a124.wav
# Extracting features for file ./data/a/a125.wav
# Extracting features for file ./data/a/a126.wav
# Extracting features for file ./data/a/a127.wav
# Extracting features for file ./data/a/a128.wav
# Extracting features for file ./data/a/a129.wav
# Extracting features for file ./data/a/a13.wav
# Extracting features for file ./data/a/a130.wav
# Extracting features for file ./data/a/a131.wav
# Extracting features for file ./data/a/a132.wav
# Extracting features for file ./data/a/a133.wav
# Extracting features for file ./data/a/a134.wav
# Extracting features for file ./data/a/a135.wav
# Extracting features for file ./data/a/a136.wav
# Extracting features for file ./data/a/a137.wav
# Extracting features for file ./data/a/a138.wav
# Extracting features for file ./data/a/a139.wav
# Extracting features for file ./data/a/a14.wav
# Extracting features for file ./data/a/a140.wav
# Extracting features for file ./data/a/a141.wav
# Extracting features for file ./data/a/a142.wav
# Extracting features for file ./data/a/a143.wav
# Extracting features for file ./data/a/a144.wav
# Extracting features for file ./data/a/a145.wav
# Extracting features for file ./data/a/a146.wav
# Extracting features for file ./data/a/a147.wav
# Extracting features for file ./data/a/a148.wav
# Extracting features for file ./data/a/a149.wav
# Extracting features for file ./data/a/a15.wav
# Extracting features for file ./data/a/a150.wav
# Extracting features for file ./data/a/a151.wav
# Extracting features for file ./data/a/a152.wav
# Extracting features for file ./data/a/a153.wav
# Extracting features for file ./data/a/a154.wav
# Extracting features for file ./data/a/a155.wav
# Extracting features for file ./data/a/a156.wav
# Extracting features for file ./data/a/a157.wav
# Extracting features for file ./data/a/a158.wav
# Extracting features for file ./data/a/a159.wav
# Extracting features for file ./data/a/a16.wav
# Extracting features for file ./data/a/a160.wav
# Extracting features for file ./data/a/a161.wav
# Extracting features for file ./data/a/a162.wav
# Extracting features for file ./data/a/a163.wav
# Extracting features for file ./data/a/a164.wav
# Extracting features for file ./data/a/a165.wav
# Extracting features for file ./data/a/a166.wav
# Extracting features for file ./data/a/a167.wav
# Extracting features for file ./data/a/a168.wav
# Extracting features for file ./data/a/a169.wav
# Extracting features for file ./data/a/a17.wav
# Extracting features for file ./data/a/a170.wav
# Extracting features for file ./data/a/a171.wav
# Extracting features for file ./data/a/a172.wav
# Extracting features for file ./data/a/a173.wav
# Extracting features for file ./data/a/a174.wav
# Extracting features for file ./data/a/a175.wav
# Extracting features for file ./data/a/a176.wav
# Extracting features for file ./data/a/a177.wav
# Extracting features for file ./data/a/a178.wav
# Extracting features for file ./data/a/a179.wav
# Extracting features for file ./data/a/a18.wav
# Extracting features for file ./data/a/a180.wav
# Extracting features for file ./data/a/a181.wav
# Extracting features for file ./data/a/a182.wav
# Extracting features for file ./data/a/a183.wav
# Extracting features for file ./data/a/a184.wav
# Extracting features for file ./data/a/a185.wav
# Extracting features for file ./data/a/a186.wav
# Extracting features for file ./data/a/a187.wav
# Extracting features for file ./data/a/a188.wav
# Extracting features for file ./data/a/a189.wav
# Extracting features for file ./data/a/a19.wav
# Extracting features for file ./data/a/a190.wav
# Extracting features for file ./data/a/a191.wav
# Extracting features for file ./data/a/a192.wav
# Extracting features for file ./data/a/a193.wav
# Extracting features for file ./data/a/a194.wav
# Extracting features for file ./data/a/a195.wav
# Extracting features for file ./data/a/a196.wav
# Extracting features for file ./data/a/a197.wav
# Extracting features for file ./data/a/a198.wav
# Extracting features for file ./data/a/a199.wav
# Extracting features for file ./data/a/a2.wav
# Extracting features for file ./data/a/a20.wav
# Extracting features for file ./data/a/a200.wav
# Extracting features for file ./data/a/a21.wav
# Extracting features for file ./data/a/a22.wav
# Extracting features for file ./data/a/a23.wav
# Extracting features for file ./data/a/a24.wav
# Extracting features for file ./data/a/a25.wav
# Extracting features for file ./data/a/a26.wav
# Extracting features for file ./data/a/a27.wav
# Extracting features for file ./data/a/a28.wav
# Extracting features for file ./data/a/a29.wav
# Extracting features for file ./data/a/a3.wav
# Extracting features for file ./data/a/a30.wav
# Extracting features for file ./data/a/a31.wav
# Extracting features for file ./data/a/a32.wav
# Extracting features for file ./data/a/a33.wav
# Extracting features for file ./data/a/a34.wav
# Extracting features for file ./data/a/a35.wav
# Extracting features for file ./data/a/a36.wav
# Extracting features for file ./data/a/a37.wav
# Extracting features for file ./data/a/a38.wav
# Extracting features for file ./data/a/a39.wav
# Extracting features for file ./data/a/a4.wav
# Extracting features for file ./data/a/a40.wav
# Extracting features for file ./data/a/a41.wav
# Extracting features for file ./data/a/a42.wav
# Extracting features for file ./data/a/a43.wav
# Extracting features for file ./data/a/a44.wav
# Extracting features for file ./data/a/a45.wav
# Extracting features for file ./data/a/a46.wav
# Extracting features for file ./data/a/a47.wav
# Extracting features for file ./data/a/a48.wav
# Extracting features for file ./data/a/a49.wav
# Extracting features for file ./data/a/a5.wav
# Extracting features for file ./data/a/a50.wav
# Extracting features for file ./data/a/a51.wav
# Extracting features for file ./data/a/a52.wav
# Extracting features for file ./data/a/a53.wav
# Extracting features for file ./data/a/a54.wav
# Extracting features for file ./data/a/a55.wav
# Extracting features for file ./data/a/a56.wav
# Extracting features for file ./data/a/a57.wav
# Extracting features for file ./data/a/a58.wav
# Extracting features for file ./data/a/a59.wav
# Extracting features for file ./data/a/a6.wav
# Extracting features for file ./data/a/a60.wav
# Extracting features for file ./data/a/a61.wav
# Extracting features for file ./data/a/a62.wav
# Extracting features for file ./data/a/a63.wav
# Extracting features for file ./data/a/a64.wav
# Extracting features for file ./data/a/a65.wav
# Extracting features for file ./data/a/a66.wav
# Extracting features for file ./data/a/a67.wav
# Extracting features for file ./data/a/a68.wav
# Extracting features for file ./data/a/a69.wav
# Extracting features for file ./data/a/a7.wav
# Extracting features for file ./data/a/a70.wav
# Extracting features for file ./data/a/a71.wav
# Extracting features for file ./data/a/a72.wav
# Extracting features for file ./data/a/a73.wav
# Extracting features for file ./data/a/a74.wav
# Extracting features for file ./data/a/a75.wav
# Extracting features for file ./data/a/a76.wav
# Extracting features for file ./data/a/a77.wav
# Extracting features for file ./data/a/a78.wav
# Extracting features for file ./data/a/a79.wav
# Extracting features for file ./data/a/a8.wav
# Extracting features for file ./data/a/a80.wav
# Extracting features for file ./data/a/a81.wav
# Extracting features for file ./data/a/a82.wav
# Extracting features for file ./data/a/a83.wav
# Extracting features for file ./data/a/a84.wav
# Extracting features for file ./data/a/a85.wav
# Extracting features for file ./data/a/a86.wav
# Extracting features for file ./data/a/a87.wav
# Extracting features for file ./data/a/a88.wav
# Extracting features for file ./data/a/a89.wav
# Extracting features for file ./data/a/a9.wav
# Extracting features for file ./data/a/a90.wav
# Extracting features for file ./data/a/a91.wav
# Extracting features for file ./data/a/a92.wav
# Extracting features for file ./data/a/a93.wav
# Extracting features for file ./data/a/a94.wav
# Extracting features for file ./data/a/a95.wav
# Extracting features for file ./data/a/a96.wav
# Extracting features for file ./data/a/a97.wav
# Extracting features for file ./data/a/a98.wav
# Extracting features for file ./data/a/a99.wav
# Extracting features for file ./data/am/am1.wav
# Extracting features for file ./data/am/am10.wav
# Extracting features for file ./data/am/am100.wav
# Extracting features for file ./data/am/am101.wav
# Extracting features for file ./data/am/am102.wav
# Extracting features for file ./data/am/am103.wav
# Extracting features for file ./data/am/am104.wav
# Extracting features for file ./data/am/am105.wav
# Extracting features for file ./data/am/am106.wav
# Extracting features for file ./data/am/am107.wav
# Extracting features for file ./data/am/am108.wav
# Extracting features for file ./data/am/am109.wav
# Extracting features for file ./data/am/am11.wav
# Extracting features for file ./data/am/am110.wav
# Extracting features for file ./data/am/am111.wav
# Extracting features for file ./data/am/am112.wav
# Extracting features for file ./data/am/am113.wav
# Extracting features for file ./data/am/am114.wav
# Extracting features for file ./data/am/am115.wav
# Extracting features for file ./data/am/am116.wav
# Extracting features for file ./data/am/am117.wav
# Extracting features for file ./data/am/am118.wav
# Extracting features for file ./data/am/am119.wav
# Extracting features for file ./data/am/am12.wav
# Extracting features for file ./data/am/am120.wav
# Extracting features for file ./data/am/am121.wav
# Extracting features for file ./data/am/am122.wav
# Extracting features for file ./data/am/am123.wav
# Extracting features for file ./data/am/am124.wav
# Extracting features for file ./data/am/am125.wav
# Extracting features for file ./data/am/am126.wav
# Extracting features for file ./data/am/am127.wav
# Extracting features for file ./data/am/am128.wav
# Extracting features for file ./data/am/am129.wav
# Extracting features for file ./data/am/am13.wav
# Extracting features for file ./data/am/am130.wav
# Extracting features for file ./data/am/am131.wav
# Extracting features for file ./data/am/am132.wav
# Extracting features for file ./data/am/am133.wav
# Extracting features for file ./data/am/am134.wav
# Extracting features for file ./data/am/am135.wav
# Extracting features for file ./data/am/am136.wav
# Extracting features for file ./data/am/am137.wav
# Extracting features for file ./data/am/am138.wav
# Extracting features for file ./data/am/am139.wav
# Extracting features for file ./data/am/am14.wav
# Extracting features for file ./data/am/am140.wav
# Extracting features for file ./data/am/am141.wav
# Extracting features for file ./data/am/am142.wav
# Extracting features for file ./data/am/am143.wav
# Extracting features for file ./data/am/am144.wav
# Extracting features for file ./data/am/am145.wav
# Extracting features for file ./data/am/am146.wav
# Extracting features for file ./data/am/am147.wav
# Extracting features for file ./data/am/am148.wav
# Extracting features for file ./data/am/am149.wav
# Extracting features for file ./data/am/am15.wav
# Extracting features for file ./data/am/am150.wav
# Extracting features for file ./data/am/am151.wav
# Extracting features for file ./data/am/am152.wav
# Extracting features for file ./data/am/am153.wav
# Extracting features for file ./data/am/am154.wav
# Extracting features for file ./data/am/am155.wav
# Extracting features for file ./data/am/am156.wav
# Extracting features for file ./data/am/am157.wav
# Extracting features for file ./data/am/am158.wav
# Extracting features for file ./data/am/am159.wav
# Extracting features for file ./data/am/am16.wav
# Extracting features for file ./data/am/am160.wav
# Extracting features for file ./data/am/am161.wav
# Extracting features for file ./data/am/am162.wav
# Extracting features for file ./data/am/am163.wav
# Extracting features for file ./data/am/am164.wav
# Extracting features for file ./data/am/am165.wav
# Extracting features for file ./data/am/am166.wav
# Extracting features for file ./data/am/am167.wav
# Extracting features for file ./data/am/am168.wav
# Extracting features for file ./data/am/am169.wav
# Extracting features for file ./data/am/am17.wav
# Extracting features for file ./data/am/am170.wav
# Extracting features for file ./data/am/am171.wav
# Extracting features for file ./data/am/am172.wav
# Extracting features for file ./data/am/am173.wav
# Extracting features for file ./data/am/am174.wav
# Extracting features for file ./data/am/am175.wav
# Extracting features for file ./data/am/am176.wav
# Extracting features for file ./data/am/am177.wav
# Extracting features for file ./data/am/am178.wav
# Extracting features for file ./data/am/am179.wav
# Extracting features for file ./data/am/am18.wav
# Extracting features for file ./data/am/am180.wav
# Extracting features for file ./data/am/am181.wav
# Extracting features for file ./data/am/am182.wav
# Extracting features for file ./data/am/am183.wav
# Extracting features for file ./data/am/am184.wav
# Extracting features for file ./data/am/am185.wav
# Extracting features for file ./data/am/am186.wav
# Extracting features for file ./data/am/am187.wav
# Extracting features for file ./data/am/am188.wav
# Extracting features for file ./data/am/am189.wav
# Extracting features for file ./data/am/am19.wav
# Extracting features for file ./data/am/am190.wav
# Extracting features for file ./data/am/am191.wav
# Extracting features for file ./data/am/am192.wav
# Extracting features for file ./data/am/am193.wav
# Extracting features for file ./data/am/am194.wav
# Extracting features for file ./data/am/am195.wav
# Extracting features for file ./data/am/am196.wav
# Extracting features for file ./data/am/am197.wav
# Extracting features for file ./data/am/am198.wav
# Extracting features for file ./data/am/am199.wav
# Extracting features for file ./data/am/am2.wav
# Extracting features for file ./data/am/am20.wav
# Extracting features for file ./data/am/am200.wav
# Extracting features for file ./data/am/am21.wav
# Extracting features for file ./data/am/am22.wav
# Extracting features for file ./data/am/am23.wav
# Extracting features for file ./data/am/am24.wav
# Extracting features for file ./data/am/am25.wav
# Extracting features for file ./data/am/am26.wav
# Extracting features for file ./data/am/am27.wav
# Extracting features for file ./data/am/am28.wav
# Extracting features for file ./data/am/am29.wav
# Extracting features for file ./data/am/am3.wav
# Extracting features for file ./data/am/am30.wav
# Extracting features for file ./data/am/am31.wav
# Extracting features for file ./data/am/am32.wav
# Extracting features for file ./data/am/am33.wav
# Extracting features for file ./data/am/am34.wav
# Extracting features for file ./data/am/am35.wav
# Extracting features for file ./data/am/am36.wav
# Extracting features for file ./data/am/am37.wav
# Extracting features for file ./data/am/am38.wav
# Extracting features for file ./data/am/am39.wav
# Extracting features for file ./data/am/am4.wav
# Extracting features for file ./data/am/am40.wav
# Extracting features for file ./data/am/am41.wav
# Extracting features for file ./data/am/am42.wav
# Extracting features for file ./data/am/am43.wav
# Extracting features for file ./data/am/am44.wav
# Extracting features for file ./data/am/am45.wav
# Extracting features for file ./data/am/am46.wav
# Extracting features for file ./data/am/am47.wav
# Extracting features for file ./data/am/am48.wav
# Extracting features for file ./data/am/am49.wav
# Extracting features for file ./data/am/am5.wav
# Extracting features for file ./data/am/am50.wav
# Extracting features for file ./data/am/am51.wav
# Extracting features for file ./data/am/am52.wav
# Extracting features for file ./data/am/am53.wav
# Extracting features for file ./data/am/am54.wav
# Extracting features for file ./data/am/am55.wav
# Extracting features for file ./data/am/am56.wav
# Extracting features for file ./data/am/am57.wav
# Extracting features for file ./data/am/am58.wav
# Extracting features for file ./data/am/am59.wav
# Extracting features for file ./data/am/am6.wav
# Extracting features for file ./data/am/am60.wav
# Extracting features for file ./data/am/am61.wav
# Extracting features for file ./data/am/am62.wav
# Extracting features for file ./data/am/am63.wav
# Extracting features for file ./data/am/am64.wav
# Extracting features for file ./data/am/am65.wav
# Extracting features for file ./data/am/am66.wav
# Extracting features for file ./data/am/am67.wav
# Extracting features for file ./data/am/am68.wav
# Extracting features for file ./data/am/am69.wav
# Extracting features for file ./data/am/am7.wav
# Extracting features for file ./data/am/am70.wav
# Extracting features for file ./data/am/am71.wav
# Extracting features for file ./data/am/am72.wav
# Extracting features for file ./data/am/am73.wav
# Extracting features for file ./data/am/am74.wav
# Extracting features for file ./data/am/am75.wav
# Extracting features for file ./data/am/am76.wav
# Extracting features for file ./data/am/am77.wav
# Extracting features for file ./data/am/am78.wav
# Extracting features for file ./data/am/am79.wav
# Extracting features for file ./data/am/am8.wav
# Extracting features for file ./data/am/am80.wav
# Extracting features for file ./data/am/am81.wav
# Extracting features for file ./data/am/am82.wav
# Extracting features for file ./data/am/am83.wav
# Extracting features for file ./data/am/am84.wav
# Extracting features for file ./data/am/am85.wav
# Extracting features for file ./data/am/am86.wav
# Extracting features for file ./data/am/am87.wav
# Extracting features for file ./data/am/am88.wav
# Extracting features for file ./data/am/am89.wav
# Extracting features for file ./data/am/am9.wav
# Extracting features for file ./data/am/am90.wav
# Extracting features for file ./data/am/am91.wav
# Extracting features for file ./data/am/am92.wav
# Extracting features for file ./data/am/am93.wav
# Extracting features for file ./data/am/am94.wav
# Extracting features for file ./data/am/am95.wav
# Extracting features for file ./data/am/am96.wav
# Extracting features for file ./data/am/am97.wav
# Extracting features for file ./data/am/am98.wav
# Extracting features for file ./data/am/am99.wav
# Extracting features for file ./data/bm/bm1.wav
# Extracting features for file ./data/bm/bm10.wav
# Extracting features for file ./data/bm/bm100.wav
# Extracting features for file ./data/bm/bm101.wav
# Extracting features for file ./data/bm/bm102.wav
# Extracting features for file ./data/bm/bm103.wav
# Extracting features for file ./data/bm/bm104.wav
# Extracting features for file ./data/bm/bm105.wav
# Extracting features for file ./data/bm/bm106.wav
# Extracting features for file ./data/bm/bm107.wav
# Extracting features for file ./data/bm/bm108.wav
# Extracting features for file ./data/bm/bm109.wav
# Extracting features for file ./data/bm/bm11.wav
# Extracting features for file ./data/bm/bm110.wav
# Extracting features for file ./data/bm/bm111.wav
# Extracting features for file ./data/bm/bm112.wav
# Extracting features for file ./data/bm/bm113.wav
# Extracting features for file ./data/bm/bm114.wav
# Extracting features for file ./data/bm/bm115.wav
# Extracting features for file ./data/bm/bm116.wav
# Extracting features for file ./data/bm/bm117.wav
# Extracting features for file ./data/bm/bm118.wav
# Extracting features for file ./data/bm/bm119.wav
# Extracting features for file ./data/bm/bm12.wav
# Extracting features for file ./data/bm/bm120.wav
# Extracting features for file ./data/bm/bm121.wav
# Extracting features for file ./data/bm/bm122.wav
# Extracting features for file ./data/bm/bm123.wav
# Extracting features for file ./data/bm/bm124.wav
# Extracting features for file ./data/bm/bm125.wav
# Extracting features for file ./data/bm/bm126.wav
# Extracting features for file ./data/bm/bm127.wav
# Extracting features for file ./data/bm/bm128.wav
# Extracting features for file ./data/bm/bm129.wav
# Extracting features for file ./data/bm/bm13.wav
# Extracting features for file ./data/bm/bm130.wav
# Extracting features for file ./data/bm/bm131.wav
# Extracting features for file ./data/bm/bm132.wav
# Extracting features for file ./data/bm/bm133.wav
# Extracting features for file ./data/bm/bm134.wav
# Extracting features for file ./data/bm/bm135.wav
# Extracting features for file ./data/bm/bm136.wav
# Extracting features for file ./data/bm/bm137.wav
# Extracting features for file ./data/bm/bm138.wav
# Extracting features for file ./data/bm/bm139.wav
# Extracting features for file ./data/bm/bm14.wav
# Extracting features for file ./data/bm/bm140.wav
# Extracting features for file ./data/bm/bm141.wav
# Extracting features for file ./data/bm/bm142.wav
# Extracting features for file ./data/bm/bm143.wav
# Extracting features for file ./data/bm/bm144.wav
# Extracting features for file ./data/bm/bm145.wav
# Extracting features for file ./data/bm/bm146.wav
# Extracting features for file ./data/bm/bm147.wav
# Extracting features for file ./data/bm/bm148.wav
# Extracting features for file ./data/bm/bm149.wav
# Extracting features for file ./data/bm/bm15.wav
# Extracting features for file ./data/bm/bm150.wav
# Extracting features for file ./data/bm/bm151.wav
# Extracting features for file ./data/bm/bm152.wav
# Extracting features for file ./data/bm/bm153.wav
# Extracting features for file ./data/bm/bm154.wav
# Extracting features for file ./data/bm/bm155.wav
# Extracting features for file ./data/bm/bm156.wav
# Extracting features for file ./data/bm/bm157.wav
# Extracting features for file ./data/bm/bm158.wav
# Extracting features for file ./data/bm/bm159.wav
# Extracting features for file ./data/bm/bm16.wav
# Extracting features for file ./data/bm/bm160.wav
# Extracting features for file ./data/bm/bm161.wav
# Extracting features for file ./data/bm/bm162.wav
# Extracting features for file ./data/bm/bm163.wav
# Extracting features for file ./data/bm/bm164.wav
# Extracting features for file ./data/bm/bm165.wav
# Extracting features for file ./data/bm/bm166.wav
# Extracting features for file ./data/bm/bm167.wav
# Extracting features for file ./data/bm/bm168.wav
# Extracting features for file ./data/bm/bm169.wav
# Extracting features for file ./data/bm/bm17.wav
# Extracting features for file ./data/bm/bm170.wav
# Extracting features for file ./data/bm/bm171.wav
# Extracting features for file ./data/bm/bm172.wav
# Extracting features for file ./data/bm/bm173.wav
# Extracting features for file ./data/bm/bm174.wav
# Extracting features for file ./data/bm/bm175.wav
# Extracting features for file ./data/bm/bm176.wav
# Extracting features for file ./data/bm/bm177.wav
# Extracting features for file ./data/bm/bm178.wav
# Extracting features for file ./data/bm/bm179.wav
# Extracting features for file ./data/bm/bm18.wav
# Extracting features for file ./data/bm/bm180.wav
# Extracting features for file ./data/bm/bm181.wav
# Extracting features for file ./data/bm/bm182.wav
# Extracting features for file ./data/bm/bm183.wav
# Extracting features for file ./data/bm/bm184.wav
# Extracting features for file ./data/bm/bm185.wav
# Extracting features for file ./data/bm/bm186.wav
# Extracting features for file ./data/bm/bm187.wav
# Extracting features for file ./data/bm/bm188.wav
# Extracting features for file ./data/bm/bm189.wav
# Extracting features for file ./data/bm/bm19.wav
# Extracting features for file ./data/bm/bm190.wav
# Extracting features for file ./data/bm/bm191.wav
# Extracting features for file ./data/bm/bm192.wav
# Extracting features for file ./data/bm/bm193.wav
# Extracting features for file ./data/bm/bm194.wav
# Extracting features for file ./data/bm/bm195.wav
# Extracting features for file ./data/bm/bm196.wav
# Extracting features for file ./data/bm/bm197.wav
# Extracting features for file ./data/bm/bm198.wav
# Extracting features for file ./data/bm/bm199.wav
# Extracting features for file ./data/bm/bm2.wav
# Extracting features for file ./data/bm/bm20.wav
# Extracting features for file ./data/bm/bm200.wav
# Extracting features for file ./data/bm/bm21.wav
# Extracting features for file ./data/bm/bm22.wav
# Extracting features for file ./data/bm/bm23.wav
# Extracting features for file ./data/bm/bm24.wav
# Extracting features for file ./data/bm/bm25.wav
# Extracting features for file ./data/bm/bm26.wav
# Extracting features for file ./data/bm/bm27.wav
# Extracting features for file ./data/bm/bm28.wav
# Extracting features for file ./data/bm/bm29.wav
# Extracting features for file ./data/bm/bm3.wav
# Extracting features for file ./data/bm/bm30.wav
# Extracting features for file ./data/bm/bm31.wav
# Extracting features for file ./data/bm/bm32.wav
# Extracting features for file ./data/bm/bm33.wav
# Extracting features for file ./data/bm/bm34.wav
# Extracting features for file ./data/bm/bm35.wav
# Extracting features for file ./data/bm/bm36.wav
# Extracting features for file ./data/bm/bm37.wav
# Extracting features for file ./data/bm/bm38.wav
# Extracting features for file ./data/bm/bm39.wav
# Extracting features for file ./data/bm/bm4.wav
# Extracting features for file ./data/bm/bm40.wav
# Extracting features for file ./data/bm/bm41.wav
# Extracting features for file ./data/bm/bm42.wav
# Extracting features for file ./data/bm/bm43.wav
# Extracting features for file ./data/bm/bm44.wav
# Extracting features for file ./data/bm/bm45.wav
# Extracting features for file ./data/bm/bm46.wav
# Extracting features for file ./data/bm/bm47.wav
# Extracting features for file ./data/bm/bm48.wav
# Extracting features for file ./data/bm/bm49.wav
# Extracting features for file ./data/bm/bm5.wav
# Extracting features for file ./data/bm/bm50.wav
# Extracting features for file ./data/bm/bm51.wav
# Extracting features for file ./data/bm/bm52.wav
# Extracting features for file ./data/bm/bm53.wav
# Extracting features for file ./data/bm/bm54.wav
# Extracting features for file ./data/bm/bm55.wav
# Extracting features for file ./data/bm/bm56.wav
# Extracting features for file ./data/bm/bm57.wav
# Extracting features for file ./data/bm/bm58.wav
# Extracting features for file ./data/bm/bm59.wav
# Extracting features for file ./data/bm/bm6.wav
# Extracting features for file ./data/bm/bm60.wav
# Extracting features for file ./data/bm/bm61.wav
# Extracting features for file ./data/bm/bm62.wav
# Extracting features for file ./data/bm/bm63.wav
# Extracting features for file ./data/bm/bm64.wav
# Extracting features for file ./data/bm/bm65.wav
# Extracting features for file ./data/bm/bm66.wav
# Extracting features for file ./data/bm/bm67.wav
# Extracting features for file ./data/bm/bm68.wav
# Extracting features for file ./data/bm/bm69.wav
# Extracting features for file ./data/bm/bm7.wav
# Extracting features for file ./data/bm/bm70.wav
# Extracting features for file ./data/bm/bm71.wav
# Extracting features for file ./data/bm/bm72.wav
# Extracting features for file ./data/bm/bm73.wav
# Extracting features for file ./data/bm/bm74.wav
# Extracting features for file ./data/bm/bm75.wav
# Extracting features for file ./data/bm/bm76.wav
# Extracting features for file ./data/bm/bm77.wav
# Extracting features for file ./data/bm/bm78.wav
# Extracting features for file ./data/bm/bm79.wav
# Extracting features for file ./data/bm/bm8.wav
# Extracting features for file ./data/bm/bm80.wav
# Extracting features for file ./data/bm/bm81.wav
# Extracting features for file ./data/bm/bm82.wav
# Extracting features for file ./data/bm/bm83.wav
# Extracting features for file ./data/bm/bm84.wav
# Extracting features for file ./data/bm/bm85.wav
# Extracting features for file ./data/bm/bm86.wav
# Extracting features for file ./data/bm/bm87.wav
# Extracting features for file ./data/bm/bm88.wav
# Extracting features for file ./data/bm/bm89.wav
# Extracting features for file ./data/bm/bm9.wav
# Extracting features for file ./data/bm/bm90.wav
# Extracting features for file ./data/bm/bm91.wav
# Extracting features for file ./data/bm/bm92.wav
# Extracting features for file ./data/bm/bm93.wav
# Extracting features for file ./data/bm/bm94.wav
# Extracting features for file ./data/bm/bm95.wav
# Extracting features for file ./data/bm/bm96.wav
# Extracting features for file ./data/bm/bm97.wav
# Extracting features for file ./data/bm/bm98.wav
# Extracting features for file ./data/bm/bm99.wav
# Extracting features for file ./data/c/c1.wav
# Extracting features for file ./data/c/c10.wav
# Extracting features for file ./data/c/c100.wav
# Extracting features for file ./data/c/c101.wav
# Extracting features for file ./data/c/c102.wav
# Extracting features for file ./data/c/c103.wav
# Extracting features for file ./data/c/c104.wav
# Extracting features for file ./data/c/c105.wav
# Extracting features for file ./data/c/c106.wav
# Extracting features for file ./data/c/c107.wav
# Extracting features for file ./data/c/c108.wav
# Extracting features for file ./data/c/c109.wav
# Extracting features for file ./data/c/c11.wav
# Extracting features for file ./data/c/c110.wav
# Extracting features for file ./data/c/c111.wav
# Extracting features for file ./data/c/c112.wav
# Extracting features for file ./data/c/c113.wav
# Extracting features for file ./data/c/c114.wav
# Extracting features for file ./data/c/c115.wav
# Extracting features for file ./data/c/c116.wav
# Extracting features for file ./data/c/c117.wav
# Extracting features for file ./data/c/c118.wav
# Extracting features for file ./data/c/c119.wav
# Extracting features for file ./data/c/c12.wav
# Extracting features for file ./data/c/c120.wav
# Extracting features for file ./data/c/c121.wav
# Extracting features for file ./data/c/c122.wav
# Extracting features for file ./data/c/c123.wav
# Extracting features for file ./data/c/c124.wav
# Extracting features for file ./data/c/c125.wav
# Extracting features for file ./data/c/c126.wav
# Extracting features for file ./data/c/c127.wav
# Extracting features for file ./data/c/c128.wav
# Extracting features for file ./data/c/c129.wav
# Extracting features for file ./data/c/c13.wav
# Extracting features for file ./data/c/c130.wav
# Extracting features for file ./data/c/c131.wav
# Extracting features for file ./data/c/c132.wav
# Extracting features for file ./data/c/c133.wav
# Extracting features for file ./data/c/c134.wav
# Extracting features for file ./data/c/c135.wav
# Extracting features for file ./data/c/c136.wav
# Extracting features for file ./data/c/c137.wav
# Extracting features for file ./data/c/c138.wav
# Extracting features for file ./data/c/c139.wav
# Extracting features for file ./data/c/c14.wav
# Extracting features for file ./data/c/c140.wav
# Extracting features for file ./data/c/c141.wav
# Extracting features for file ./data/c/c142.wav
# Extracting features for file ./data/c/c143.wav
# Extracting features for file ./data/c/c144.wav
# Extracting features for file ./data/c/c145.wav
# Extracting features for file ./data/c/c146.wav
# Extracting features for file ./data/c/c147.wav
# Extracting features for file ./data/c/c148.wav
# Extracting features for file ./data/c/c149.wav
# Extracting features for file ./data/c/c15.wav
# Extracting features for file ./data/c/c150.wav
# Extracting features for file ./data/c/c151.wav
# Extracting features for file ./data/c/c152.wav
# Extracting features for file ./data/c/c153.wav
# Extracting features for file ./data/c/c154.wav
# Extracting features for file ./data/c/c155.wav
# Extracting features for file ./data/c/c156.wav
# Extracting features for file ./data/c/c157.wav
# Extracting features for file ./data/c/c158.wav
# Extracting features for file ./data/c/c159.wav
# Extracting features for file ./data/c/c16.wav
# Extracting features for file ./data/c/c160.wav
# Extracting features for file ./data/c/c161.wav
# Extracting features for file ./data/c/c162.wav
# Extracting features for file ./data/c/c163.wav
# Extracting features for file ./data/c/c164.wav
# Extracting features for file ./data/c/c165.wav
# Extracting features for file ./data/c/c166.wav
# Extracting features for file ./data/c/c167.wav
# Extracting features for file ./data/c/c168.wav
# Extracting features for file ./data/c/c169.wav
# Extracting features for file ./data/c/c17.wav
# Extracting features for file ./data/c/c170.wav
# Extracting features for file ./data/c/c171.wav
# Extracting features for file ./data/c/c172.wav
# Extracting features for file ./data/c/c173.wav
# Extracting features for file ./data/c/c174.wav
# Extracting features for file ./data/c/c175.wav
# Extracting features for file ./data/c/c176.wav
# Extracting features for file ./data/c/c177.wav
# Extracting features for file ./data/c/c178.wav
# Extracting features for file ./data/c/c179.wav
# Extracting features for file ./data/c/c18.wav
# Extracting features for file ./data/c/c180.wav
# Extracting features for file ./data/c/c181.wav
# Extracting features for file ./data/c/c182.wav
# Extracting features for file ./data/c/c183.wav
# Extracting features for file ./data/c/c184.wav
# Extracting features for file ./data/c/c185.wav
# Extracting features for file ./data/c/c186.wav
# Extracting features for file ./data/c/c187.wav
# Extracting features for file ./data/c/c188.wav
# Extracting features for file ./data/c/c189.wav
# Extracting features for file ./data/c/c19.wav
# Extracting features for file ./data/c/c190.wav
# Extracting features for file ./data/c/c191.wav
# Extracting features for file ./data/c/c192.wav
# Extracting features for file ./data/c/c193.wav
# Extracting features for file ./data/c/c194.wav
# Extracting features for file ./data/c/c195.wav
# Extracting features for file ./data/c/c196.wav
# Extracting features for file ./data/c/c197.wav
# Extracting features for file ./data/c/c198.wav
# Extracting features for file ./data/c/c199.wav
# Extracting features for file ./data/c/c2.wav
# Extracting features for file ./data/c/c20.wav
# Extracting features for file ./data/c/c200.wav
# Extracting features for file ./data/c/c21.wav
# Extracting features for file ./data/c/c22.wav
# Extracting features for file ./data/c/c23.wav
# Extracting features for file ./data/c/c24.wav
# Extracting features for file ./data/c/c25.wav
# Extracting features for file ./data/c/c26.wav
# Extracting features for file ./data/c/c27.wav
# Extracting features for file ./data/c/c28.wav
# Extracting features for file ./data/c/c29.wav
# Extracting features for file ./data/c/c3.wav
# Extracting features for file ./data/c/c30.wav
# Extracting features for file ./data/c/c31.wav
# Extracting features for file ./data/c/c32.wav
# Extracting features for file ./data/c/c33.wav
# Extracting features for file ./data/c/c34.wav
# Extracting features for file ./data/c/c35.wav
# Extracting features for file ./data/c/c36.wav
# Extracting features for file ./data/c/c37.wav
# Extracting features for file ./data/c/c38.wav
# Extracting features for file ./data/c/c39.wav
# Extracting features for file ./data/c/c4.wav
# Extracting features for file ./data/c/c40.wav
# Extracting features for file ./data/c/c41.wav
# Extracting features for file ./data/c/c42.wav
# Extracting features for file ./data/c/c43.wav
# Extracting features for file ./data/c/c44.wav
# Extracting features for file ./data/c/c45.wav
# Extracting features for file ./data/c/c46.wav
# Extracting features for file ./data/c/c47.wav
# Extracting features for file ./data/c/c48.wav
# Extracting features for file ./data/c/c49.wav
# Extracting features for file ./data/c/c5.wav
# Extracting features for file ./data/c/c50.wav
# Extracting features for file ./data/c/c51.wav
# Extracting features for file ./data/c/c52.wav
# Extracting features for file ./data/c/c53.wav
# Extracting features for file ./data/c/c54.wav
# Extracting features for file ./data/c/c55.wav
# Extracting features for file ./data/c/c56.wav
# Extracting features for file ./data/c/c57.wav
# Extracting features for file ./data/c/c58.wav
# Extracting features for file ./data/c/c59.wav
# Extracting features for file ./data/c/c6.wav
# Extracting features for file ./data/c/c60.wav
# Extracting features for file ./data/c/c61.wav
# Extracting features for file ./data/c/c62.wav
# Extracting features for file ./data/c/c63.wav
# Extracting features for file ./data/c/c64.wav
# Extracting features for file ./data/c/c65.wav
# Extracting features for file ./data/c/c66.wav
# Extracting features for file ./data/c/c67.wav
# Extracting features for file ./data/c/c68.wav
# Extracting features for file ./data/c/c69.wav
# Extracting features for file ./data/c/c7.wav
# Extracting features for file ./data/c/c70.wav
# Extracting features for file ./data/c/c71.wav
# Extracting features for file ./data/c/c72.wav
# Extracting features for file ./data/c/c73.wav
# Extracting features for file ./data/c/c74.wav
# Extracting features for file ./data/c/c75.wav
# Extracting features for file ./data/c/c76.wav
# Extracting features for file ./data/c/c77.wav
# Extracting features for file ./data/c/c78.wav
# Extracting features for file ./data/c/c79.wav
# Extracting features for file ./data/c/c8.wav
# Extracting features for file ./data/c/c80.wav
# Extracting features for file ./data/c/c81.wav
# Extracting features for file ./data/c/c82.wav
# Extracting features for file ./data/c/c83.wav
# Extracting features for file ./data/c/c84.wav
# Extracting features for file ./data/c/c85.wav
# Extracting features for file ./data/c/c86.wav
# Extracting features for file ./data/c/c87.wav
# Extracting features for file ./data/c/c88.wav
# Extracting features for file ./data/c/c89.wav
# Extracting features for file ./data/c/c9.wav
# Extracting features for file ./data/c/c90.wav
# Extracting features for file ./data/c/c91.wav
# Extracting features for file ./data/c/c92.wav
# Extracting features for file ./data/c/c93.wav
# Extracting features for file ./data/c/c94.wav
# Extracting features for file ./data/c/c95.wav
# Extracting features for file ./data/c/c96.wav
# Extracting features for file ./data/c/c97.wav
# Extracting features for file ./data/c/c98.wav
# Extracting features for file ./data/c/c99.wav
# Extracting features for file ./data/d/d1.wav
# Extracting features for file ./data/d/d10.wav
# Extracting features for file ./data/d/d100.wav
# Extracting features for file ./data/d/d101.wav
# Extracting features for file ./data/d/d102.wav
# Extracting features for file ./data/d/d103.wav
# Extracting features for file ./data/d/d104.wav
# Extracting features for file ./data/d/d105.wav
# Extracting features for file ./data/d/d106.wav
# Extracting features for file ./data/d/d107.wav
# Extracting features for file ./data/d/d108.wav
# Extracting features for file ./data/d/d109.wav
# Extracting features for file ./data/d/d11.wav
# Extracting features for file ./data/d/d110.wav
# Extracting features for file ./data/d/d111.wav
# Extracting features for file ./data/d/d112.wav
# Extracting features for file ./data/d/d113.wav
# Extracting features for file ./data/d/d114.wav
# Extracting features for file ./data/d/d115.wav
# Extracting features for file ./data/d/d116.wav
# Extracting features for file ./data/d/d117.wav
# Extracting features for file ./data/d/d118.wav
# Extracting features for file ./data/d/d119.wav
# Extracting features for file ./data/d/d12.wav
# Extracting features for file ./data/d/d120.wav
# Extracting features for file ./data/d/d121.wav
# Extracting features for file ./data/d/d122.wav
# Extracting features for file ./data/d/d123.wav
# Extracting features for file ./data/d/d124.wav
# Extracting features for file ./data/d/d125.wav
# Extracting features for file ./data/d/d126.wav
# Extracting features for file ./data/d/d127.wav
# Extracting features for file ./data/d/d128.wav
# Extracting features for file ./data/d/d129.wav
# Extracting features for file ./data/d/d13.wav
# Extracting features for file ./data/d/d130.wav
# Extracting features for file ./data/d/d131.wav
# Extracting features for file ./data/d/d132.wav
# Extracting features for file ./data/d/d133.wav
# Extracting features for file ./data/d/d134.wav
# Extracting features for file ./data/d/d135.wav
# Extracting features for file ./data/d/d136.wav
# Extracting features for file ./data/d/d137.wav
# Extracting features for file ./data/d/d138.wav
# Extracting features for file ./data/d/d139.wav
# Extracting features for file ./data/d/d14.wav
# Extracting features for file ./data/d/d140.wav
# Extracting features for file ./data/d/d141.wav
# Extracting features for file ./data/d/d142.wav
# Extracting features for file ./data/d/d143.wav
# Extracting features for file ./data/d/d144.wav
# Extracting features for file ./data/d/d145.wav
# Extracting features for file ./data/d/d146.wav
# Extracting features for file ./data/d/d147.wav
# Extracting features for file ./data/d/d148.wav
# Extracting features for file ./data/d/d149.wav
# Extracting features for file ./data/d/d15.wav
# Extracting features for file ./data/d/d150.wav
# Extracting features for file ./data/d/d151.wav
# Extracting features for file ./data/d/d152.wav
# Extracting features for file ./data/d/d153.wav
# Extracting features for file ./data/d/d154.wav
# Extracting features for file ./data/d/d155.wav
# Extracting features for file ./data/d/d156.wav
# Extracting features for file ./data/d/d157.wav
# Extracting features for file ./data/d/d158.wav
# Extracting features for file ./data/d/d159.wav
# Extracting features for file ./data/d/d16.wav
# Extracting features for file ./data/d/d160.wav
# Extracting features for file ./data/d/d161.wav
# Extracting features for file ./data/d/d162.wav
# Extracting features for file ./data/d/d163.wav
# Extracting features for file ./data/d/d164.wav
# Extracting features for file ./data/d/d165.wav
# Extracting features for file ./data/d/d166.wav
# Extracting features for file ./data/d/d167.wav
# Extracting features for file ./data/d/d168.wav
# Extracting features for file ./data/d/d169.wav
# Extracting features for file ./data/d/d17.wav
# Extracting features for file ./data/d/d170.wav
# Extracting features for file ./data/d/d171.wav
# Extracting features for file ./data/d/d172.wav
# Extracting features for file ./data/d/d173.wav
# Extracting features for file ./data/d/d174.wav
# Extracting features for file ./data/d/d175.wav
# Extracting features for file ./data/d/d176.wav
# Extracting features for file ./data/d/d177.wav
# Extracting features for file ./data/d/d178.wav
# Extracting features for file ./data/d/d179.wav
# Extracting features for file ./data/d/d18.wav
# Extracting features for file ./data/d/d180.wav
# Extracting features for file ./data/d/d181.wav
# Extracting features for file ./data/d/d182.wav
# Extracting features for file ./data/d/d183.wav
# Extracting features for file ./data/d/d184.wav
# Extracting features for file ./data/d/d185.wav
# Extracting features for file ./data/d/d186.wav
# Extracting features for file ./data/d/d187.wav
# Extracting features for file ./data/d/d188.wav
# Extracting features for file ./data/d/d189.wav
# Extracting features for file ./data/d/d19.wav
# Extracting features for file ./data/d/d190.wav
# Extracting features for file ./data/d/d191.wav
# Extracting features for file ./data/d/d192.wav
# Extracting features for file ./data/d/d193.wav
# Extracting features for file ./data/d/d194.wav
# Extracting features for file ./data/d/d195.wav
# Extracting features for file ./data/d/d196.wav
# Extracting features for file ./data/d/d197.wav
# Extracting features for file ./data/d/d198.wav
# Extracting features for file ./data/d/d199.wav
# Extracting features for file ./data/d/d2.wav
# Extracting features for file ./data/d/d20.wav
# Extracting features for file ./data/d/d200.wav
# Extracting features for file ./data/d/d21.wav
# Extracting features for file ./data/d/d22.wav
# Extracting features for file ./data/d/d23.wav
# Extracting features for file ./data/d/d24.wav
# Extracting features for file ./data/d/d25.wav
# Extracting features for file ./data/d/d26.wav
# Extracting features for file ./data/d/d27.wav
# Extracting features for file ./data/d/d28.wav
# Extracting features for file ./data/d/d29.wav
# Extracting features for file ./data/d/d3.wav
# Extracting features for file ./data/d/d30.wav
# Extracting features for file ./data/d/d31.wav
# Extracting features for file ./data/d/d32.wav
# Extracting features for file ./data/d/d33.wav
# Extracting features for file ./data/d/d34.wav
# Extracting features for file ./data/d/d35.wav
# Extracting features for file ./data/d/d36.wav
# Extracting features for file ./data/d/d37.wav
# Extracting features for file ./data/d/d38.wav
# Extracting features for file ./data/d/d39.wav
# Extracting features for file ./data/d/d4.wav
# Extracting features for file ./data/d/d40.wav
# Extracting features for file ./data/d/d41.wav
# Extracting features for file ./data/d/d42.wav
# Extracting features for file ./data/d/d43.wav
# Extracting features for file ./data/d/d44.wav
# Extracting features for file ./data/d/d45.wav
# Extracting features for file ./data/d/d46.wav
# Extracting features for file ./data/d/d47.wav
# Extracting features for file ./data/d/d48.wav
# Extracting features for file ./data/d/d49.wav
# Extracting features for file ./data/d/d5.wav
# Extracting features for file ./data/d/d50.wav
# Extracting features for file ./data/d/d51.wav
# Extracting features for file ./data/d/d52.wav
# Extracting features for file ./data/d/d53.wav
# Extracting features for file ./data/d/d54.wav
# Extracting features for file ./data/d/d55.wav
# Extracting features for file ./data/d/d56.wav
# Extracting features for file ./data/d/d57.wav
# Extracting features for file ./data/d/d58.wav
# Extracting features for file ./data/d/d59.wav
# Extracting features for file ./data/d/d6.wav
# Extracting features for file ./data/d/d60.wav
# Extracting features for file ./data/d/d61.wav
# Extracting features for file ./data/d/d62.wav
# Extracting features for file ./data/d/d63.wav
# Extracting features for file ./data/d/d64.wav
# Extracting features for file ./data/d/d65.wav
# Extracting features for file ./data/d/d66.wav
# Extracting features for file ./data/d/d67.wav
# Extracting features for file ./data/d/d68.wav
# Extracting features for file ./data/d/d69.wav
# Extracting features for file ./data/d/d7.wav
# Extracting features for file ./data/d/d70.wav
# Extracting features for file ./data/d/d71.wav
# Extracting features for file ./data/d/d72.wav
# Extracting features for file ./data/d/d73.wav
# Extracting features for file ./data/d/d74.wav
# Extracting features for file ./data/d/d75.wav
# Extracting features for file ./data/d/d76.wav
# Extracting features for file ./data/d/d77.wav
# Extracting features for file ./data/d/d78.wav
# Extracting features for file ./data/d/d79.wav
# Extracting features for file ./data/d/d8.wav
# Extracting features for file ./data/d/d80.wav
# Extracting features for file ./data/d/d81.wav
# Extracting features for file ./data/d/d82.wav
# Extracting features for file ./data/d/d83.wav
# Extracting features for file ./data/d/d84.wav
# Extracting features for file ./data/d/d85.wav
# Extracting features for file ./data/d/d86.wav
# Extracting features for file ./data/d/d87.wav
# Extracting features for file ./data/d/d88.wav
# Extracting features for file ./data/d/d89.wav
# Extracting features for file ./data/d/d9.wav
# Extracting features for file ./data/d/d90.wav
# Extracting features for file ./data/d/d91.wav
# Extracting features for file ./data/d/d92.wav
# Extracting features for file ./data/d/d93.wav
# Extracting features for file ./data/d/d94.wav
# Extracting features for file ./data/d/d95.wav
# Extracting features for file ./data/d/d96.wav
# Extracting features for file ./data/d/d97.wav
# Extracting features for file ./data/d/d98.wav
# Extracting features for file ./data/d/d99.wav
# Extracting features for file ./data/dm/dm1.wav
# Extracting features for file ./data/dm/dm10.wav
# Extracting features for file ./data/dm/dm100.wav
# Extracting features for file ./data/dm/dm101.wav
# Extracting features for file ./data/dm/dm102.wav
# Extracting features for file ./data/dm/dm103.wav
# Extracting features for file ./data/dm/dm104.wav
# Extracting features for file ./data/dm/dm105.wav
# Extracting features for file ./data/dm/dm106.wav
# Extracting features for file ./data/dm/dm107.wav
# Extracting features for file ./data/dm/dm108.wav
# Extracting features for file ./data/dm/dm109.wav
# Extracting features for file ./data/dm/dm11.wav
# Extracting features for file ./data/dm/dm110.wav
# ...
# Extracting features for file ./data/f/f15.wav
# Extracting features for file ./data/f/f150.wav
# Extracting features for file ./data/f/f151.wav
# Extracting features for file ./data/f/f152.wav
# Extracting features for file ./data/f/f153.wav
# Extracting features for file ./data/f/f154.wav
# Extracting features for file ./data/f/f155.wav
# Extracting features for file ./data/f/f156.wav
# Extracting features for file ./data/f/f157.wav
# Extracting features for file ./data/f/f158.wav
# Extracting features for file ./data/f/f159.wav
# Extracting features for file ./data/f/f16.wav
# Extracting features for file ./data/f/f160.wav
# Extracting features for file ./data/f/f161.wav
# Extracting features for file ./data/f/f162.wav
# Extracting features for file ./data/f/f163.wav
# Extracting features for file ./data/f/f164.wav
# Extracting features for file ./data/f/f165.wav
# Extracting features for file ./data/f/f166.wav
# Extracting features for file ./data/f/f167.wav
# Extracting features for file ./data/f/f168.wav
# Extracting features for file ./data/f/f169.wav
# Extracting features for file ./data/f/f17.wav
# Extracting features for file ./data/f/f170.wav
# Extracting features for file ./data/f/f171.wav
# Extracting features for file ./data/f/f172.wav
# Extracting features for file ./data/f/f173.wav
# Extracting features for file ./data/f/f174.wav
# Extracting features for file ./data/f/f175.wav
# Extracting features for file ./data/f/f176.wav
# Extracting features for file ./data/f/f177.wav
# Extracting features for file ./data/f/f178.wav
# Extracting features for file ./data/f/f179.wav
# Extracting features for file ./data/f/f18.wav
# Extracting features for file ./data/f/f180.wav
# Extracting features for file ./data/f/f181.wav
# Extracting features for file ./data/f/f182.wav
# Extracting features for file ./data/f/f183.wav
# Extracting features for file ./data/f/f184.wav
# Extracting features for file ./data/f/f185.wav
# Extracting features for file ./data/f/f186.wav
# Extracting features for file ./data/f/f187.wav
# Extracting features for file ./data/f/f188.wav
# Extracting features for file ./data/f/f189.wav
# Extracting features for file ./data/f/f19.wav
# Extracting features for file ./data/f/f190.wav
# Extracting features for file ./data/f/f191.wav
# Extracting features for file ./data/f/f192.wav
# Extracting features for file ./data/f/f193.wav
# Extracting features for file ./data/f/f194.wav
# Extracting features for file ./data/f/f195.wav
# Extracting features for file ./data/f/f196.wav
# Extracting features for file ./data/f/f197.wav
# Extracting features for file ./data/f/f198.wav
# Extracting features for file ./data/f/f199.wav
# Extracting features for file ./data/f/f2.wav
# Extracting features for file ./data/f/f20.wav
# Extracting features for file ./data/f/f200.wav
# Extracting features for file ./data/f/f21.wav
# Extracting features for file ./data/f/f22.wav
# Extracting features for file ./data/f/f23.wav
# Extracting features for file ./data/f/f24.wav
# Extracting features for file ./data/f/f25.wav
# Extracting features for file ./data/f/f26.wav
# Extracting features for file ./data/f/f27.wav
# Extracting features for file ./data/f/f28.wav
# Extracting features for file ./data/f/f29.wav
# Extracting features for file ./data/f/f3.wav
# Extracting features for file ./data/f/f30.wav
# Extracting features for file ./data/f/f31.wav
# Extracting features for file ./data/f/f32.wav
# Extracting features for file ./data/f/f33.wav
# Extracting features for file ./data/f/f34.wav
# Extracting features for file ./data/f/f35.wav
# Extracting features for file ./data/f/f36.wav
# Extracting features for file ./data/f/f37.wav
# Extracting features for file ./data/f/f38.wav
# Extracting features for file ./data/f/f39.wav
# Extracting features for file ./data/f/f4.wav
# Extracting features for file ./data/f/f40.wav
# Extracting features for file ./data/f/f41.wav
# Extracting features for file ./data/f/f42.wav
# Extracting features for file ./data/f/f43.wav
# Extracting features for file ./data/f/f44.wav
# Extracting features for file ./data/f/f45.wav
# Extracting features for file ./data/f/f46.wav
# Extracting features for file ./data/f/f47.wav
# Extracting features for file ./data/f/f48.wav
# Extracting features for file ./data/f/f49.wav
# Extracting features for file ./data/f/f5.wav
# Extracting features for file ./data/f/f50.wav
# Extracting features for file ./data/f/f51.wav
# Extracting features for file ./data/f/f52.wav
# Extracting features for file ./data/f/f53.wav
# Extracting features for file ./data/f/f54.wav
# Extracting features for file ./data/f/f55.wav
# Extracting features for file ./data/f/f56.wav
# Extracting features for file ./data/f/f57.wav
# Extracting features for file ./data/f/f58.wav
# Extracting features for file ./data/f/f59.wav
# Extracting features for file ./data/f/f6.wav
# Extracting features for file ./data/f/f60.wav
# Extracting features for file ./data/f/f61.wav
# Extracting features for file ./data/f/f62.wav
# Extracting features for file ./data/f/f63.wav
# Extracting features for file ./data/f/f64.wav
# Extracting features for file ./data/f/f65.wav
# Extracting features for file ./data/f/f66.wav
# Extracting features for file ./data/f/f67.wav
# Extracting features for file ./data/f/f68.wav
# Extracting features for file ./data/f/f69.wav
# Extracting features for file ./data/f/f7.wav
# Extracting features for file ./data/f/f70.wav
# Extracting features for file ./data/f/f71.wav
# Extracting features for file ./data/f/f72.wav
# Extracting features for file ./data/f/f73.wav
# Extracting features for file ./data/f/f74.wav
# Extracting features for file ./data/f/f75.wav
# Extracting features for file ./data/f/f76.wav
# Extracting features for file ./data/f/f77.wav
# Extracting features for file ./data/f/f78.wav
# Extracting features for file ./data/f/f79.wav
# Extracting features for file ./data/f/f8.wav
# Extracting features for file ./data/f/f80.wav
# Extracting features for file ./data/f/f81.wav
# Extracting features for file ./data/f/f82.wav
# Extracting features for file ./data/f/f83.wav
# Extracting features for file ./data/f/f84.wav
# Extracting features for file ./data/f/f85.wav
# Extracting features for file ./data/f/f86.wav
# Extracting features for file ./data/f/f87.wav
# Extracting features for file ./data/f/f88.wav
# Extracting features for file ./data/f/f89.wav
# Extracting features for file ./data/f/f9.wav
# Extracting features for file ./data/f/f90.wav
# Extracting features for file ./data/f/f91.wav
# Extracting features for file ./data/f/f92.wav
# Extracting features for file ./data/f/f93.wav
# Extracting features for file ./data/f/f94.wav
# Extracting features for file ./data/f/f95.wav
# Extracting features for file ./data/f/f96.wav
# Extracting features for file ./data/f/f97.wav
# Extracting features for file ./data/f/f98.wav
# Extracting features for file ./data/f/f99.wav
# Extracting features for file ./data/g/g1.wav
# Extracting features for file ./data/g/g10.wav
# Extracting features for file ./data/g/g100.wav
# Extracting features for file ./data/g/g101.wav
# Extracting features for file ./data/g/g102.wav
# Extracting features for file ./data/g/g103.wav
# Extracting features for file ./data/g/g104.wav
# Extracting features for file ./data/g/g105.wav
# Extracting features for file ./data/g/g106.wav
# Extracting features for file ./data/g/g107.wav
# Extracting features for file ./data/g/g108.wav
# Extracting features for file ./data/g/g109.wav
# Extracting features for file ./data/g/g11.wav
# Extracting features for file ./data/g/g110.wav
# Extracting features for file ./data/g/g111.wav
# Extracting features for file ./data/g/g112.wav
# Extracting features for file ./data/g/g113.wav
# Extracting features for file ./data/g/g114.wav
# Extracting features for file ./data/g/g115.wav
# Extracting features for file ./data/g/g116.wav
# Extracting features for file ./data/g/g117.wav
# Extracting features for file ./data/g/g118.wav
# Extracting features for file ./data/g/g119.wav
# Extracting features for file ./data/g/g12.wav
# Extracting features for file ./data/g/g120.wav
# Extracting features for file ./data/g/g121.wav
# Extracting features for file ./data/g/g122.wav
# Extracting features for file ./data/g/g123.wav
# Extracting features for file ./data/g/g124.wav
# Extracting features for file ./data/g/g125.wav
# Extracting features for file ./data/g/g126.wav
# Extracting features for file ./data/g/g127.wav
# Extracting features for file ./data/g/g128.wav
# Extracting features for file ./data/g/g129.wav
# Extracting features for file ./data/g/g13.wav
# Extracting features for file ./data/g/g130.wav
# Extracting features for file ./data/g/g131.wav
# Extracting features for file ./data/g/g132.wav
# Extracting features for file ./data/g/g133.wav
# Extracting features for file ./data/g/g134.wav
# Extracting features for file ./data/g/g135.wav
# Extracting features for file ./data/g/g136.wav
# Extracting features for file ./data/g/g137.wav
# Extracting features for file ./data/g/g138.wav
# Extracting features for file ./data/g/g139.wav
# Extracting features for file ./data/g/g14.wav
# Extracting features for file ./data/g/g140.wav
# Extracting features for file ./data/g/g141.wav
# Extracting features for file ./data/g/g142.wav
# Extracting features for file ./data/g/g143.wav
# Extracting features for file ./data/g/g144.wav
# Extracting features for file ./data/g/g145.wav
# Extracting features for file ./data/g/g146.wav
# Extracting features for file ./data/g/g147.wav
# Extracting features for file ./data/g/g148.wav
# Extracting features for file ./data/g/g149.wav
# Extracting features for file ./data/g/g15.wav
# Extracting features for file ./data/g/g150.wav
# Extracting features for file ./data/g/g151.wav
# Extracting features for file ./data/g/g152.wav
# Extracting features for file ./data/g/g153.wav
# Extracting features for file ./data/g/g154.wav
# Extracting features for file ./data/g/g155.wav
# Extracting features for file ./data/g/g156.wav
# Extracting features for file ./data/g/g157.wav
# Extracting features for file ./data/g/g158.wav
# Extracting features for file ./data/g/g159.wav
# Extracting features for file ./data/g/g16.wav
# Extracting features for file ./data/g/g160.wav
# Extracting features for file ./data/g/g161.wav
# Extracting features for file ./data/g/g162.wav
# Extracting features for file ./data/g/g163.wav
# Extracting features for file ./data/g/g164.wav
# Extracting features for file ./data/g/g165.wav
# Extracting features for file ./data/g/g166.wav
# Extracting features for file ./data/g/g167.wav
# Extracting features for file ./data/g/g168.wav
# Extracting features for file ./data/g/g169.wav
# Extracting features for file ./data/g/g17.wav
# Extracting features for file ./data/g/g170.wav
# Extracting features for file ./data/g/g171.wav
# Extracting features for file ./data/g/g172.wav
# Extracting features for file ./data/g/g173.wav
# Extracting features for file ./data/g/g174.wav
# Extracting features for file ./data/g/g175.wav
# Extracting features for file ./data/g/g176.wav
# Extracting features for file ./data/g/g177.wav
# Extracting features for file ./data/g/g178.wav
# Extracting features for file ./data/g/g179.wav
# Extracting features for file ./data/g/g18.wav
# Extracting features for file ./data/g/g180.wav
# Extracting features for file ./data/g/g181.wav
# Extracting features for file ./data/g/g182.wav
# Extracting features for file ./data/g/g183.wav
# Extracting features for file ./data/g/g184.wav
# Extracting features for file ./data/g/g185.wav
# Extracting features for file ./data/g/g186.wav
# Extracting features for file ./data/g/g187.wav
# Extracting features for file ./data/g/g188.wav
# Extracting features for file ./data/g/g189.wav
# Extracting features for file ./data/g/g19.wav
# Extracting features for file ./data/g/g190.wav
# Extracting features for file ./data/g/g191.wav
# Extracting features for file ./data/g/g192.wav
# Extracting features for file ./data/g/g193.wav
# Extracting features for file ./data/g/g194.wav
# Extracting features for file ./data/g/g195.wav
# Extracting features for file ./data/g/g196.wav
# Extracting features for file ./data/g/g197.wav
# Extracting features for file ./data/g/g198.wav
# Extracting features for file ./data/g/g199.wav
# Extracting features for file ./data/g/g2.wav
# Extracting features for file ./data/g/g20.wav
# Extracting features for file ./data/g/g200.wav
# Extracting features for file ./data/g/g21.wav
# Extracting features for file ./data/g/g22.wav
# Extracting features for file ./data/g/g23.wav
# Extracting features for file ./data/g/g24.wav
# Extracting features for file ./data/g/g25.wav
# Extracting features for file ./data/g/g26.wav
# Extracting features for file ./data/g/g27.wav
# Extracting features for file ./data/g/g28.wav
# Extracting features for file ./data/g/g29.wav
# Extracting features for file ./data/g/g3.wav
# Extracting features for file ./data/g/g30.wav
# Extracting features for file ./data/g/g31.wav
# Extracting features for file ./data/g/g32.wav
# Extracting features for file ./data/g/g33.wav
# Extracting features for file ./data/g/g34.wav
# Extracting features for file ./data/g/g35.wav
# Extracting features for file ./data/g/g36.wav
# Extracting features for file ./data/g/g37.wav
# Extracting features for file ./data/g/g38.wav
# Extracting features for file ./data/g/g39.wav
# Extracting features for file ./data/g/g4.wav
# Extracting features for file ./data/g/g40.wav
# Extracting features for file ./data/g/g41.wav
# Extracting features for file ./data/g/g42.wav
# Extracting features for file ./data/g/g43.wav
# Extracting features for file ./data/g/g44.wav
# Extracting features for file ./data/g/g45.wav
# Extracting features for file ./data/g/g46.wav
# Extracting features for file ./data/g/g47.wav
# Extracting features for file ./data/g/g48.wav
# Extracting features for file ./data/g/g49.wav
# Extracting features for file ./data/g/g5.wav
# Extracting features for file ./data/g/g50.wav
# Extracting features for file ./data/g/g51.wav
# Extracting features for file ./data/g/g52.wav
# Extracting features for file ./data/g/g53.wav
# Extracting features for file ./data/g/g54.wav
# Extracting features for file ./data/g/g55.wav
# Extracting features for file ./data/g/g56.wav
# Extracting features for file ./data/g/g57.wav
# Extracting features for file ./data/g/g58.wav
# Extracting features for file ./data/g/g59.wav
# Extracting features for file ./data/g/g6.wav
# Extracting features for file ./data/g/g60.wav
# Extracting features for file ./data/g/g61.wav
# Extracting features for file ./data/g/g62.wav
# Extracting features for file ./data/g/g63.wav
# Extracting features for file ./data/g/g64.wav
# Extracting features for file ./data/g/g65.wav
# Extracting features for file ./data/g/g66.wav
# Extracting features for file ./data/g/g67.wav
# Extracting features for file ./data/g/g68.wav
# Extracting features for file ./data/g/g69.wav
# Extracting features for file ./data/g/g7.wav
# Extracting features for file ./data/g/g70.wav
# Extracting features for file ./data/g/g71.wav
# Extracting features for file ./data/g/g72.wav
# Extracting features for file ./data/g/g73.wav
# Extracting features for file ./data/g/g74.wav
# Extracting features for file ./data/g/g75.wav
# Extracting features for file ./data/g/g76.wav
# Extracting features for file ./data/g/g77.wav
# Extracting features for file ./data/g/g78.wav
# Extracting features for file ./data/g/g79.wav
# Extracting features for file ./data/g/g8.wav
# Extracting features for file ./data/g/g80.wav
# Extracting features for file ./data/g/g81.wav
# Extracting features for file ./data/g/g82.wav
# Extracting features for file ./data/g/g83.wav
# Extracting features for file ./data/g/g84.wav
# Extracting features for file ./data/g/g85.wav
# Extracting features for file ./data/g/g86.wav
# Extracting features for file ./data/g/g87.wav
# Extracting features for file ./data/g/g88.wav
# Extracting features for file ./data/g/g89.wav
# Extracting features for file ./data/g/g9.wav
# Extracting features for file ./data/g/g90.wav
# Extracting features for file ./data/g/g91.wav
# Extracting features for file ./data/g/g92.wav
# Extracting features for file ./data/g/g93.wav
# Extracting features for file ./data/g/g94.wav
# Extracting features for file ./data/g/g95.wav
# Extracting features for file ./data/g/g96.wav
# Extracting features for file ./data/g/g97.wav
# Extracting features for file ./data/g/g98.wav
# Extracting features for file ./data/g/g99.wav
# =====FEATURE EXTRACTION COMPLETE=====

# %%
#We use this lookup table for getting chord labels instead of proper metadata -- for now
chordNames = {'a' : 'A:Maj', 
              'am' : 'A:Min',
              'bm' : 'B:Min',
              'c' : 'C:Maj',
              'd' : 'D:Maj',
              'dm' : 'D:Min',
              'e' : 'E:Maj',
              'em' : 'E:Min',
              'f' : 'F:Maj',
              'g' : 'G:Maj'}
### REPLACE THE CLASS NAME LOOKUP METHODOLOGY WITH THE METADATA LABELS



#We will use this list for assigning numbers to classes
chordClasses = chordNames.values();

# #Create empty dataframe
X = pd.DataFrame()
y = pd.DataFrame()

#Read chroma features from disk and create the whole dataset in matrix form
for subdir, dirs, files in os.walk(featuresRootDir):
    for file in files:
        if file[0] == ".":
            continue #This is for avoiding .DS_Store and similar files
        filename, file_extension = os.path.splitext(file)
        if file_extension[-4:] == ".npy" and filename[-3:] == "_st":
            rootDir, subDirName = os.path.split(subdir)
            chordName = chordNames[subDirName]
            chordClass = chordClasses.index(chordName)
            stFeatures = np.load(subdir + "/" + file)
            chromaStream = chromaStream = np.transpose(stFeatures[21:33,:])
        
            ### REPLACE THE CLASS NAME LOOKUP METHODOLOGY WITH THE METADATA LABELS
            classLabels = np.array([chordClass] * chromaStream.shape[0]);
            ### REPLACE THE CLASS NAME LOOKUP METHODOLOGY WITH THE METADATA LABELS
            
            tmpX = pd.DataFrame(chromaStream)
            tmpY = pd.DataFrame(classLabels)
            X = X.append(tmpX)
            y = y.append(tmpY)
            
#After this, we have the data in X and the class labels in y. Now it is ready for sklearn training

print(X.shape)
print(y.shape)
# Out:
# (156397, 12)
# (156397, 1)

# %%
## Simple algorithm trial to see that the training works
print("==Decision Tree==")
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
scores = cross_val_score(clf, X, y, cv=fold, scoring="accuracy")
print("Cross-validation error = %f +-%f" % (1. - np.mean(scores), np.std(scores)))

# %%
##Start doing the experiments below with different methods and parameters
print("==Support Vector Machine==")
from sklearn.svm import SVC
clf = SVC(kernel="rbf")
scores = cross_val_score(clf, X, y, cv=fold, scoring="accuracy")
print("Cross-validation error = %f +-%f" % (1. - np.mean(scores), np.std(scores)))
